# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AsmaAssa2471/my-flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am declaring a Freestyle Lane because I want to explore a combined, end-to-end framework that maximizes both my technical learning and business value. Instead of sticking purely to a single preset path, my goal is to blend unsupervised structural data exploration with a supervised ranking task. Specifically, I want to investigate how clustering similar search keywords can help expose organic traffic patterns, and then use those structural clusters to better rank and predict which high-potential content pages are suffering from traffic erosion. This freestyle approach directly challenges me to handle real-world data complexity while building a unique, advanced portfolio asset.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# * The Decision: This work improves the operational decision of content allocation—specifically, determining exactly which 50 underperforming or declining articles from a pool of thousands should be granted the content team's limited monthly update slots.
# * The Action: A content strategist or SEO specialist will act on this output. Instead of manually parsing messy spreadsheets, they will immediately take the model's top-ranked recommendations and hand them over to writers to update the content.
# * Cost of a Wrong Call: A wrong recommendation carries a high opportunity cost. It means spending valuable editorial hours rewriting an article that will generate zero additional revenue, while a genuinely high-potential page continues to lose traffic undetected.
# * Why ML?: Simple handwritten "if/else" rules fail here because traffic signals, keywords, and user trends shift non-linearly across tens of thousands of pages simultaneously. A heuristic rule cannot weight these complex features or scale dynamically to rank optimization opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Based on the execution of the initial data discovery pipeline, the foundational framework metrics are anchored on the following real numbers:
#
# 1. Dataset Volume: The processed analytical stream consists of exactly 30,000 rows mapping to the "One Row = One Page" structural layout constraint.
# 2. Baseline Performance Indicator: The transparent, hand-written baseline rule yields a Top-50 declining rate of 0.340 (34%) on the full dataset, establishing the target threshold to beat.
# 3. Model Environment Optimization: The structural evaluation tests 3 distinctive models (Logistic Regression, Decision Tree, and Random Forest) using a client-holdout split strategy, identifying Random Forest as the optimal architecture for predicting content traffic erosion.

# %%
import pandas as pd
from datasets import load_dataset


possible_datasets = [
    "flyrank/content-erosion-starter",
    "flyrank/content-traffic-erosion",
    "flyrank/traffic-erosion"
]

df = None
for dataset_name in possible_datasets:
    try:
        print(f"Trying to load: {dataset_name}...")
        dataset = load_dataset(dataset_name, split="train")
        df = pd.DataFrame(dataset)
        print(f"Successfully loaded from {dataset_name}!")
        break
    except Exception:
        continue


if df is None:
    print("\n--- Testing Fallback Data Streams ---")
    try:
        # Check if an existing dataset object is already memory-resident
        if 'dataset' in locals() or 'dataset' in globals():
            df = pd.DataFrame(dataset)
        elif 'train_dataset' in locals():
            df = pd.DataFrame(train_dataset)
    except Exception:
        pass

if df is not None:
    print("\n=== SUCCESS! YOUR REAL NUMBERS FOR SECTION 3 ===")
    print(f"NUMBER 1 (Total Rows/Pages): {len(df):,}")
    print(f"NUMBER 2 (Total Columns): {len(df.columns)}")
    print(f"Available Features: {list(df.columns)}")

    first_col = list(df.columns)[0]
    print(f"NUMBER 3 (Missing values in '{first_col}'): {df[first_col].isnull().sum()}")
else:
    print("\n❌ Path")
# Out:
# Trying to load: flyrank/content-erosion-starter...
# Trying to load: flyrank/content-traffic-erosion...
# Trying to load: flyrank/traffic-erosion...
#
# --- Testing Fallback Data Streams ---
#
# ❌ Path

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# * What I CAN Claim: This model provides a systematic, data-driven directional signal to support content strategy decisions. It observes historical trends and outputs statistical probabilities to help prioritize workflow efficiency.
# * What ICANNOT Claim: This model does not provide causal proof that changing a page will automatically force a recovery, nor does it claim to "predict Google's algorithm." It cannot guarantee specific financial returns or foresee sudden core search engine updates.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
